# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
#import keras
from tensorflow import keras

# %%
al = plt.imread('/content/fivehund_images/img_300.jpg')
#al = al*255

w = al.shape[1]  #store the width
h = al.shape[0]  #store the height

up = np.zeros((int((w-h)/2),w))
down = np.zeros((int((w-h)/2),w))

carree0 = np.vstack((up,al[:,:,0],down))
carree1 = np.vstack((up,al[:,:,1],down))
carree2 = np.vstack((up,al[:,:,2],down))

merge = cv2.merge([carree0,carree1,carree2])

thebig = cv2.resize(merge, (112, 112), interpolation=cv2.INTER_NEAREST)


plt.imshow(thebig.astype(np.uint8))
plt.show()
print(thebig.shape)
# Out:
# (112, 112, 3)

# %%
al = plt.imread('/content/fivehund_images/img_200.jpg')


w = al.shape[1]  #store the width
h = al.shape[0]  #store the height
c = al.shape[2]  #store the number of channels(3 in this case)

# In case image is horizontally orientated
if w > h:
  up = np.zeros((int((w-h)/2),w))
  down = np.zeros((int((w-h)/2),w))

  carree0 = np.vstack((up,al[:,:,0],down))
  resized0 = cv2.resize(carree0, (112, 112), interpolation=cv2.INTER_NEAREST)

  carree1 = np.vstack((up,al[:,:,1],down))
  resized1 = cv2.resize(carree1, (112, 112), interpolation=cv2.INTER_NEAREST) 

  carree2 = np.vstack((up,al[:,:,2],down))
  resized2 = cv2.resize(carree2, (112, 112), interpolation=cv2.INTER_NEAREST)

  #carree3 = np.vstack((up,al[:,:,3],down))
  #resized3 = cv2.resize(carree3, (112, 112), interpolation=cv2.INTER_NEAREST)

  resized = cv2.merge([resized0,resized1,resized2])

# In case image is vertically orientated
elif w < h:
  left = np.zeros((h,int((h-w)/2)))
  right = np.zeros((h,int((h-w)/2)))


  square0 = np.column_stack((left,al[:,:,0],right))
  resized0 = cv2.resize(square0, (112, 112), interpolation=cv2.INTER_NEAREST)

  square1 = np.column_stack((left,al[:,:,1],right))
  resized1 = cv2.resize(square1, (112, 112), interpolation=cv2.INTER_NEAREST)

  square2 = np.column_stack((left,al[:,:,2],right))
  resized2 = cv2.resize(square2, (112, 112), interpolation=cv2.INTER_NEAREST)

  #square3 = np.column_stack((left,al[:,:,3],right))
  #resized3 = cv2.resize(square3, (112, 112), interpolation=cv2.INTER_NEAREST)

  resized = cv2.merge([resized0,resized1,resized2])

# In case image is squared
else:
  resized0 = cv2.resize(al[:,:,0], (112, 112), interpolation=cv2.INTER_NEAREST)
  resized1 = cv2.resize(al[:,:,1], (112, 112), interpolation=cv2.INTER_NEAREST)
  resized2 = cv2.resize(al[:,:,2], (112, 112), interpolation=cv2.INTER_NEAREST)
  #resized3 = cv2.resize(al[:,:,3], (112, 112), interpolation=cv2.INTER_NEAREST)

  resized = cv2.merge([resized0,resized1,resized2])

al = resized 

plt.imshow(al.astype(np.uint8))  # to Clip input data to the valid range for imshow with RGB data.
plt.show()
print(al.shape)
print(c)

#X[i,] = np.load('data/' + ID + '.npy')  #load the image (np.array)
# Out:
# (112, 112, 3)
# 3

# %% [markdown]
# ### resizing the images

# %%
al = plt.imread('/content/fivehund_images/img_100.jpg')


w = al.shape[1]  #store the width
h = al.shape[0]  #store the height
c = al.shape[2]  #store the number of channels(3 in this case)

# In case image is horizontally orientated
if w > h:
  up = np.zeros((int((w-h)/2),w))
  down = np.zeros((int((w-h)/2),w))

  on_each_channel = []

  for i in range(c):
    caree = np.vstack((up,al[:,:,i],down))
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)



# In case image is vertically orientated
elif w < h:
  left = np.zeros((h,int((h-w)/2)))
  right = np.zeros((h,int((h-w)/2)))

  on_each_channel = []

  for i in range(c):
    caree = np.vstack((left,al[:,:,i],right))
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)


# In case image is squared
else:

  on_each_channel = []

  for i in range(c):
    caree = al[:,:,i]
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)


al = RESIZED 

plt.imshow(al.astype(np.uint8))  # to Clip input data to the valid range for imshow with RGB data.
plt.show()
print(al.shape)
# Out:
# (112, 112, 3)

# %% [markdown]
# ### resizing the masks

# %%
ali = plt.imread('/content/fivehund_masks/fivehund_masks/img_100.jpg')


w = ali.shape[1]  #store the width
h = ali.shape[0]  #store the height
c = ali.shape[2]  #store the number of channels(3 in this case)

# In case image is horizontally orientated
if w > h:
  up = np.zeros((int((w-h)/2),w))
  down = np.zeros((int((w-h)/2),w))

  on_each_channel = []

  for i in range(c):
    caree = np.vstack((up,ali[:,:,i],down))
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)



# In case image is vertically orientated
elif w < h:
  left = np.zeros((h,int((h-w)/2)))
  right = np.zeros((h,int((h-w)/2)))

  on_each_channel = []

  for i in range(c):
    caree = np.vstack((left,ali[:,:,i],right))
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)


# In case image is squared
else:

  on_each_channel = []

  for i in range(c):
    caree = ali[:,:,i]
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)


ali = RESIZED 

plt.imshow((ali*255).astype(np.uint8))  # to Clip input data to the valid range for imshow with RGB data.
plt.show()
print(ali.shape)
# Out:
# (112, 112, 3)

# %% [markdown]
# ### resizing the distance_geo

# %%
ale = np.load('/content/fivehund_distancegeo/fivehund_distancegeo/img_100.npy')


w = ale.shape[1]  #store the width
h = ale.shape[0]  #store the height
c = ale.shape[2]  #store the number of channels(3 in this case)

# In case image is horizontally orientated
if w > h:
  up = np.zeros((int((w-h)/2),w))
  down = np.zeros((int((w-h)/2),w))

  on_each_channel = []

  for i in range(c):
    caree = np.vstack((up,ale[:,:,i],down))
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)



# In case image is vertically orientated
elif w < h:
  left = np.zeros((h,int((h-w)/2)))
  right = np.zeros((h,int((h-w)/2)))

  on_each_channel = []

  for i in range(c):
    caree = np.vstack((left,ale[:,:,i],right))
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)


# In case image is squared
else:

  on_each_channel = []

  for i in range(c):
    caree = ale[:,:,i]
    resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
    on_each_channel.append(resized)

  RESIZED = cv2.merge(on_each_channel)


ale = RESIZED 

#plt.imshow(al.astype(np.uint8))  # to Clip input data to the valid range for imshow with RGB data.
#plt.show()

print(ale.shape)

for el in range(c):

  plt.imshow(ale[:,:,i])
  plt.show()
  print(ale[:,:,i].shape)
# Out:
# (112, 112, 4)
# (112, 112)
# (112, 112)
# (112, 112)
# (112, 112)

# %%
import matplotlib.pyplot as plt
import cv2

# %%
from skimage import io, color

# %% [markdown]
# ## This section will be repeated multiple times due to a memory shortage, all the data could not be processed at once

# %% [markdown]
# ## Preprocessing before data generation

# %%
import pandas as pd

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/east/fivehund/fiveh
npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_255.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_256.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_257.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_258.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_259.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_260.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_261.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_262.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_263.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_264.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_265.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_266.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_267.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_268.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_269.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_270.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_271.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_272.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_273.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_274.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_275.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_276.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_277.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_278.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_279.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_280.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_281.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_282.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_283.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_284.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_285.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_286.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_287.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_288.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_289.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_290.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_291.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_292.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_293.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_294.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_295.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_296.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_297.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_298.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_299.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_300.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_301.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_302.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_303.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_304.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_305.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_306.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_307.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_308.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_309.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_310.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_311.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_312.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_313.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_314.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_315.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_316.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_317.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_318.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_319.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_320.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_321.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_322.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_323.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_324.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_325.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_326.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_327.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_328.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_329.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_330.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_331.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_332.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_333.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_334.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_335.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_336.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_337.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_338.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_339.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_340.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_341.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_342.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_343.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_344.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_345.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_346.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_347.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_348.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_349.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_350.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_351.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_352.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_353.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_354.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_355.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_356.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_357.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_358.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_359.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_360.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_361.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_362.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_363.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_364.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_365.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_366.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_367.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_368.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_369.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_370.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_371.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_372.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_373.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_374.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_375.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_376.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_377.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_378.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_379.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_380.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_381.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_382.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_383.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_384.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_385.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_386.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_387.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_388.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_389.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_390.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_391.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_392.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_393.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_394.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_395.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_396.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_397.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_398.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_399.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_400.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_401.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_402.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_403.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_404.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_405.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_406.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_407.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_408.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_409.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_410.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_411.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_412.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_413.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_414.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_415.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_416.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_417.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_418.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_419.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_420.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_421.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_422.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_423.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_424.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_425.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_426.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_427.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_428.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_429.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_430.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_431.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_432.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_433.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_434.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_435.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_436.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_437.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_438.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_439.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_440.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_441.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_442.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_443.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_444.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_445.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_446.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_447.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_448.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_449.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_450.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_451.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_452.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_453.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_454.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_455.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_456.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_457.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_458.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_459.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_460.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_461.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_462.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_463.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_464.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_465.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_466.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_467.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_468.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_469.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_470.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_471.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_472.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_473.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_474.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_475.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_476.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_477.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_478.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_479.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_480.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_481.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_482.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_483.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_484.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_485.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_486.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_487.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_488.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_489.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_490.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_491.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_492.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_493.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_494.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_495.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_496.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_497.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_498.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_499.npy
#   inflating: /content/fivehund_distancegeo/fivehund_distancegeo/img_500.npy

# %%
import glob2

# %%
#be careful during the unzip as a new folder could be created 
dataset_type = 'fivehund_images'
images = glob2.glob(f'/content/{dataset_type}/*.jpg')

# %%
blabla = images[:10]
blabla.sort()  # .sort() does not return anything but it does affect the list directly
blabla
# Out:
# ['/content/fivehund_images/img_121.jpg',
#  '/content/fivehund_images/img_213.jpg',
#  '/content/fivehund_images/img_290.jpg',
#  '/content/fivehund_images/img_293.jpg',
#  '/content/fivehund_images/img_339.jpg',
#  '/content/fivehund_images/img_446.jpg',
#  '/content/fivehund_images/img_472.jpg',
#  '/content/fivehund_images/img_499.jpg',
#  '/content/fivehund_images/img_75.jpg',
#  '/content/fivehund_images/img_95.jpg']

# %%
sorted(blabla)  # sorted() otherwise does return the sorted list
# Out:
# ['/content/fivehund_images/img_121.jpg',
#  '/content/fivehund_images/img_213.jpg',
#  '/content/fivehund_images/img_290.jpg',
#  '/content/fivehund_images/img_293.jpg',
#  '/content/fivehund_images/img_339.jpg',
#  '/content/fivehund_images/img_446.jpg',
#  '/content/fivehund_images/img_472.jpg',
#  '/content/fivehund_images/img_499.jpg',
#  '/content/fivehund_images/img_75.jpg',
#  '/content/fivehund_images/img_95.jpg']

# %%
frame_images = pd.DataFrame(blabla, columns=['names']).sort_values(by=['names'], ascending = True).reset_index(drop=True)

# %%
frame_images
# Out:
#                                   names
# 0  /content/fivehund_images/img_121.jpg
# 1  /content/fivehund_images/img_213.jpg
# 2  /content/fivehund_images/img_290.jpg
# 3  /content/fivehund_images/img_293.jpg
# 4  /content/fivehund_images/img_339.jpg
# 5  /content/fivehund_images/img_446.jpg
# 6  /content/fivehund_images/img_472.jpg
# 7  /content/fivehund_images/img_499.jpg
# 8   /content/fivehund_images/img_75.jpg
# 9   /content/fivehund_images/img_95.jpg

# %%
#be careful during the unzip as a new folder could be created 
dataset_type = 'fivehund_masks'
list_of_masks = glob2.glob(f'/content/{dataset_type}/{dataset_type}/*.jpg')

# %%
boo = list_of_masks[:10]
frame_masks = pd.DataFrame(boo, columns=['masks']).sort_values(by=['masks'], ascending=True).reset_index(drop=True)
frame_masks
# Out:
#                                                masks
# 0  /content/fivehund_masks/fivehund_masks/img_121...
# 1  /content/fivehund_masks/fivehund_masks/img_213...
# 2  /content/fivehund_masks/fivehund_masks/img_290...
# 3  /content/fivehund_masks/fivehund_masks/img_293...
# 4  /content/fivehund_masks/fivehund_masks/img_339...
# 5  /content/fivehund_masks/fivehund_masks/img_446...
# 6  /content/fivehund_masks/fivehund_masks/img_472...
# 7  /content/fivehund_masks/fivehund_masks/img_499...
# 8  /content/fivehund_masks/fivehund_masks/img_75.jpg
# 9  /content/fivehund_masks/fivehund_masks/img_95.jpg

# %%
pd.concat([frame_images, frame_masks], axis=1)
# Out:
#                                   names                                              masks
# 0  /content/fivehund_images/img_121.jpg  /content/fivehund_masks/fivehund_masks/img_121...
# 1  /content/fivehund_images/img_213.jpg  /content/fivehund_masks/fivehund_masks/img_213...
# 2  /content/fivehund_images/img_290.jpg  /content/fivehund_masks/fivehund_masks/img_290...
# 3  /content/fivehund_images/img_293.jpg  /content/fivehund_masks/fivehund_masks/img_293...
# 4  /content/fivehund_images/img_339.jpg  /content/fivehund_masks/fivehund_masks/img_339...
# 5  /content/fivehund_images/img_446.jpg  /content/fivehund_masks/fivehund_masks/img_446...
# 6  /content/fivehund_images/img_472.jpg  /content/fivehund_masks/fivehund_masks/img_472...
# 7  /content/fivehund_images/img_499.jpg  /content/fivehund_masks/fivehund_masks/img_499...
# 8   /content/fivehund_images/img_75.jpg  /content/fivehund_masks/fivehund_masks/img_75.jpg
# 9   /content/fivehund_images/img_95.jpg  /content/fivehund_masks/fivehund_masks/img_95.jpg

# %%
#be careful during the unzip as a new folder could be created 
dataset_type = 'fivehund_distancegeo'
list_of_distancegeo = glob2.glob(f'/content/{dataset_type}/{dataset_type}/*.npy')

# %%
def processdata(dataset_name):

  ''' This function aims to create a dataframe that stored the name, mask and distancegeo for each image'''

  #store into lists the names, masks and distancegeo
  list_of_images = glob2.glob(f'/content/{dataset_name}_images/*.jpg')
  list_of_masks = glob2.glob(f'/content/{dataset_name}_masks/{dataset_name}_masks/*.jpg')
  list_of_distancegeo = glob2.glob(f'/content/{dataset_name}_distancegeo/{dataset_name}_distancegeo/*.npy')

  #make a flatten list
  raw_lists = [list_of_images, list_of_masks, list_of_distancegeo]

  #sort the values by ascending order
  sorted_list_of_images, sorted_list_of_masks, sorted_list_of_distancegeo = [sorted(x) for x in raw_lists]

  #store lists into dataframes
  frame_images = pd.DataFrame(sorted_list_of_images, columns=['names']).sort_values(by=['names'], ascending=True).reset_index(drop=True)
  frame_masks = pd.DataFrame(sorted_list_of_masks, columns=['masks']).sort_values(by=['masks'], ascending=True).reset_index(drop=True)
  frame_distancegeo = pd.DataFrame(sorted_list_of_distancegeo, columns=['distancegeo']).sort_values(by=['distancegeo'], ascending=True).reset_index(drop=True)

  #concatenate dataframes
  df = pd.concat([frame_images, frame_masks, frame_distancegeo], axis=1)
  df.to_csv(r'./df_fivehund.csv', index = False)
  
  return df

# %%
def main():
    processdata('fivehund')
    
if __name__ == "__main__":
    main()

# %%
myframe = pd.read_csv('df_fivehund.csv')

# %%
myframe
# Out:
#                                     names  ...                                        distancegeo
# 0      /content/fivehund_images/img_1.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 1     /content/fivehund_images/img_10.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 2    /content/fivehund_images/img_100.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 3    /content/fivehund_images/img_101.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 4    /content/fivehund_images/img_102.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# ..                                    ...  ...                                                ...
# 495   /content/fivehund_images/img_95.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 496   /content/fivehund_images/img_96.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 497   /content/fivehund_images/img_97.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 498   /content/fivehund_images/img_98.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 499   /content/fivehund_images/img_99.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
#
# [500 rows x 3 columns]

# %%
ls
# Out:
# df_fivehund.csv  fivehund_distancegeo/  fivehund_masks/
# drive/           fivehund_images/       sample_data/

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'


    # Check if after redimensionning the values inside 
    #def __init__(self, list_IDs, labels, batch_size=32, dim=(32,32,32), n_channels=1,
    #             n_classes=10, shuffle=True):
      
    
        #'Initialization'
    #      very Scikit-Learn-Like in the implementation
    #    attribute names  similar to variable names

    #    self.dim = dim # tuple
    #    self.batch_size = batch_size # integer
    #    self.labels = labels # list
    #    self.list_IDs = list_IDs # list
    #    self.n_channels = n_channels # integer
    #    self.n_classes = n_classes # integer

    #    self.shuffle = shuffle # boolean

    #    self.on_epoch_end() # if we want the data to be shuffled (~indexes) we need to call this function at the initialization !

    #    self.indexes = None ( we could have initialized an empty list of indexes)

    def __init__(self, batch_size, df, shuffle=True):

      self.batch_size = batch_size
      self.df = df
      self.shuffle = shuffle


    def __len__(self):
        'Denotes the number of batches per epoch'
        mylist = df.index.to_list()

        return int(np.floor(len(mylist) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        # index = position we are interested in
        # for example index = 2
        # with batch_size = 4
        # indexes = self.indexes[2*4:(2+1)*4]
        # indexes =  self.indexes[8:12]  - which is compatible with a batch of size 4

        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        # In this implementation : we have the list_IDs (original ids)
        # We have their index position (shuffled)
        # Now, we want to get the IDS corresponding to this shuffled data
        # comprehension list

        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # equivalent to :

        # list_IDs_temp = []
        # for k in indexes:
        #   list_IDs_temp.append(self.list_IDs[k])

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'

        # function called @ each epoch end
        # list_IDS has been stored in self.list_IDs when initialized
        # we are taking all index

        # the attribute index ( self.index) did not exist at initialization
        self.indexes = np.arange(len(self.list_IDs))

        # we shuffle all index (@ each epoch)
        if self.shuffle == True: # boolean attribute
            np.random.shuffle(self.indexes)


    #def array_resized(self, )


    def name_generation(self, dataframe, batch_size):
      'Generates data names following batch_size samples'

      #k = 19
      n_batch = batch_size
      for k in range(int(len(dataframe)/batch_size)):

        
        boom = dataframe.iloc[k*n_batch:(k+1)*n_batch, :]

        pure_images = []
        pure_masks = []
        pure_distancegeo = []

        for pure in boom['names']:

        #resizing the images

          al = plt.imread(pure)


          w = al.shape[1]  #store the width
          h = al.shape[0]  #store the height
          c = al.shape[2]  #store the number of channels(3 in this case)

          # In case image is horizontally orientated
          if w > h:
            up = np.zeros((int((w-h)/2),w))
            down = np.zeros((int((w-h)/2),w))

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the ideal padding and the resize
              caree = np.vstack((up,al[:,:,i],down))
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel) #merge into the same tensor



          # In case image is vertically orientated
          elif w < h:
            left = np.zeros((h,int((h-w)/2)))
            right = np.zeros((h,int((h-w)/2)))

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the ideal padding and the resize
              caree = np.vstack((left,al[:,:,i],right))
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel)  #merge into the same tensor


          # In case image is squared
          else:

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the resize
              caree = al[:,:,i]
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel)  #merge into the same tensor


          al = RESIZED 

          pure_images.append(al)


        for mask in boom['masks']:

          ali = plt.imread(mask)


          w = ali.shape[1]  #store the width
          h = ali.shape[0]  #store the height
          c = ali.shape[2]  #store the number of channels(3 in this case)

          # In case image is horizontally orientated
          if w > h:
            up = np.zeros((int((w-h)/2),w))
            down = np.zeros((int((w-h)/2),w))

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the ideal padding and the resize
              caree = np.vstack((up,ali[:,:,i],down))
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel) #merge into the same tensor



          # In case image is vertically orientated
          elif w < h:
            left = np.zeros((h,int((h-w)/2)))
            right = np.zeros((h,int((h-w)/2)))

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the ideal padding and the resize
              caree = np.vstack((left,ali[:,:,i],right))
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel) #merge into the same tensor


          # In case image is squared
          else:

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the resize
              caree = ali[:,:,i]
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel)  #merge into the same tensor


          ali = RESIZED 
          pure_masks.append(ali)

        for distance in boom['distancegeo']:

          ale = np.load(distance)


          w = ale.shape[1]  #store the width
          h = ale.shape[0]  #store the height
          c = ale.shape[2]  #store the number of channels(3 in this case)

          # In case image is horizontally orientated
          if w > h:
            up = np.zeros((int((w-h)/2),w))
            down = np.zeros((int((w-h)/2),w))

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the ideal padding and the resize
              caree = np.vstack((up,ale[:,:,i],down))
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel)  #merge them into the same tensor



          # In case image is vertically orientated
          elif w < h:
            left = np.zeros((h,int((h-w)/2)))
            right = np.zeros((h,int((h-w)/2)))

            on_each_channel = []

            for i in range(c):
              #for each iteration, do the ideal padding and the resize
              caree = np.vstack((left,ale[:,:,i],right))
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel)  #mergen them into the same tensor


          # In case image is squared
          else:

            on_each_channel = [] 

            for i in range(c):
              #for each iteration, do the resize
              caree = ale[:,:,i]
              resized = cv2.resize(caree, (112, 112), interpolation=cv2.INTER_NEAREST)
              on_each_channel.append(resized)

            RESIZED = cv2.merge(on_each_channel)  #merge them into the same tensor


          ale = RESIZED 
          pure_distancegeo.append(ale)  # add to the list of distancegeo

        


        les_y = []  #empty list
        les_y.append(pure_masks)  #add the list of masks 
        les_y.append(pure_distancegeo)  # add the list of distancegeo

        list_de_sortie = []  #empty list
        list_de_sortie.append(pure_images)  #add the list of images
        list_de_sortie.append(les_y)   #add the list of the y
        

        yield list_de_sortie   #return this list of two lists


 


    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)

        # Initialization
        # for using the input in NN
        # ll images should have the same size

        # create empty np.empty(batch_size, 32,32, 1)
        X = np.empty((self.batch_size, *self.dim, self.n_channels))

        # creates an empty array for y (same first dimension as X)
        y = np.empty((self.batch_size), dtype=int)

        # Generate data

        # thanks to enumerate we can get the index position and the value
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            # reads in the data stored as .npy arrays  those numpy arays are @ the right format !

            X[i,] = np.load('data/' + ID + '.npy')  #load the image (np.array)

            w = X[i,].shape[1]  #store the width
            h = X[i,].shape[0]  #store the height
            
            # In case image is horizontally orientated
            if w > h:
              up = np.zeros(((w-h)/2,w))
              down = np.zeros(((w-h)/2,w))
              carree = np.vstack((up,X[i,],down))  #do a vertical padding
              resized = cv2.resize(carree, (112, 112), interpolation=cv2.INTER_NEAREST) #resize 

            # In case image is vertically orientated
            elif w < h:
              left = np.zeros((h,(h-w)/2))
              right = np.zeros((h,(h-w)/2))
              square = np.column_stack((left,X[i,],right)) #do a horizontal padding
              resized = cv2.resize(square, (112, 112), interpolation=cv2.INTER_NEAREST)  #resize
            # In case image is squared
            else:
              resized = cv2.resize(X[i,], (112, 112), interpolation=cv2.INTER_NEAREST)  #resize






            # Store class
            y[i] = self.labels[ID]

        # the output is transformed into 1-hot encoded vector
        return X, keras.utils.to_categorical(y, num_classes=self.n_classes)





  
meteor = DataGenerator(batch_size=10, df=myframe)
myGen = meteor.name_generation(myframe,10)

for el in myGen:
  print(len(el))
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-a8a296f34abd> in <module>()
#     359 myGen = meteor.name_generation(myframe,10)
#     360
# --> 361 for el in myGen:
#     362   print(len(el))
#     363
#
# <ipython-input-96-a8a296f34abd> in name_generation(self, dataframe, batch_size)
#     223         for distance in boom['distancegeo']:
#     224
# --> 225           ale = np.load(distance)
#     226
#     227
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438             else:
#     439                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 440                                          pickle_kwargs=pickle_kwargs)
#     441         else:
#     442             # Try a pickle
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     739         if isfileobj(fp):
#     740             # We can use the fast fromfile() function.
# --> 741             array = numpy.fromfile(fp, dtype=dtype, count=count)
#     742         else:
#     743             # This is not a real file. We have to read it the
#
# KeyboardInterrupt:

# %%
int(len(dataframe)/batch_size)

# %%
import PIL
try:
    import Image
except ImportError:
    from PIL import Image

# %%
k = 60
n_batch = 4
smallframe = myframe.iloc[k*n_batch:(k+1)*n_batch, :]

# %%
smallframe['names']
# Out:
# 240    /content/fivehund_images/img_315.jpg
# 241    /content/fivehund_images/img_316.jpg
# 242    /content/fivehund_images/img_317.jpg
# 243    /content/fivehund_images/img_318.jpg
# Name: names, dtype: object

# %% [markdown]
# ### Load the images and store them to a list

# %%
blog_images = []  #create an empty list 
for thing in smallframe['names']:  #iterate over the 'names' column
  im = plt.imread(thing)  #load the image
  blog_images.append(im)  #append to the list
  #im.shape
  #im = im*255

  #plot the image
  plt.title(thing)
  plt.imshow(im)
  plt.show()
  print(im.shape)  #print its shape
# Out:
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)

# %%
len(blog_images)
# Out:
# 4

# %% [markdown]
# ### Load the masks and store them to a list

# %%
blog_masks = []  #create an empty list 
for thing in smallframe['masks']:  #iterate over the column 'masks'
  im = plt.imread(thing)  #load the image
  im = im*255  #multiply by 255
  blog_masks.append(im)  #append to the list
  #im.shape
  #im = im*255

  #plot the image
  plt.title(thing)  
  plt.imshow(im) 
  plt.show()
  print(im.shape) #print its shape

  #plot the image
  #plt.title(thing[:,:,0])  
  plt.imshow(im[:,:,2]) 
  plt.show()
  print(im[:,:,0].shape) #print its shape
# Out:
# (720, 1280, 3)
# (720, 1280)
# (720, 1280, 3)
# (720, 1280)
# (720, 1280, 3)
# (720, 1280)
# (720, 1280, 3)
# (720, 1280)

# %%
len(blog_masks)
# Out:
# 4

# %% [markdown]
# ### Load the distancegeo and store them to a list

# %%
blog_distancegeo = []  #create an empty list to store the distancegeo
for thing in smallframe['distancegeo']:  #iterate over the 'distancegeo' column
  im = np.load(thing) #load the .npy file 
  #im_reshape = im.reshape(im.shape[1], im.shape[2], -1) #reshape it as it does fit the order 
  blog_distancegeo.append(im)  #append it to the list
  print(im.shape)  #print its shape
# Out:
# (720, 1280, 4)
# (720, 1280, 4)
# (720, 1280, 4)
# (720, 1280, 4)

# %%
len(blog_distancegeo)
# Out:
# 4

# %%
les_y = []
les_y.append(blog_masks)
les_y.append(blog_distancegeo)

# %%
len(les_y)
# Out:
# 2

# %%
ama = cv2.merge([first_channel,second_channel,third_channel,fourth_channel])

# %%
# Out:
# array([[[False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False],
#         ...,
#         [False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False]],
#
#        [[False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False],
#         ...,
#         [False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False]],
#
#        [[False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False],
#         ...,
#         [False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False]],
#
#        ...,
#
#        [[False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False],
#         ...,
#         [False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False]],
#
#        [[False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False],
#         ...,
#         [False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False]],
#
#        [[False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False],
#         ...,
#         [False, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False]]])

# %%
ima = np.load("/content/fivehund_distancegeo/fivehund_distancegeo/img_122.npy")

first_channel = ima[:, :, 0]
plt.imshow(first_channel)
plt.show()
print(first_channel.shape)

second_channel = ima[:, :, 1]
plt.imshow(second_channel)
plt.show()
print(second_channel.shape)
#ima

third_channel = ima[:, :, 2]
plt.imshow(third_channel)
plt.show()
print(third_channel.shape)

fourth_channel = ima[:, :, 3]
plt.imshow(fourth_channel)
plt.show()
print(fourth_channel.shape)
# Out:
# (720, 1280)
# (720, 1280)
# (720, 1280)
# (720, 1280)

# %%
smallframe['distancegeo']
# Out:
# 480    /content/fivehund_distancegeo/fivehund_distanc...
# 481    /content/fivehund_distancegeo/fivehund_distanc...
# 482    /content/fivehund_distancegeo/fivehund_distanc...
# 483    /content/fivehund_distancegeo/fivehund_distanc...
# 484    /content/fivehund_distancegeo/fivehund_distanc...
# 485    /content/fivehund_distancegeo/fivehund_distanc...
# 486    /content/fivehund_distancegeo/fivehund_distanc...
# 487    /content/fivehund_distancegeo/fivehund_distanc...
# Name: distancegeo, dtype: object

# %%
myframe
# Out:
#                                     names  ...                                        distancegeo
# 0      /content/fivehund_images/img_1.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 1     /content/fivehund_images/img_10.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 2    /content/fivehund_images/img_100.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 3    /content/fivehund_images/img_101.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 4    /content/fivehund_images/img_102.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# ..                                    ...  ...                                                ...
# 495   /content/fivehund_images/img_95.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 496   /content/fivehund_images/img_96.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 497   /content/fivehund_images/img_97.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 498   /content/fivehund_images/img_98.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
# 499   /content/fivehund_images/img_99.jpg  ...  /content/fivehund_distancegeo/fivehund_distanc...
#
# [500 rows x 3 columns]
